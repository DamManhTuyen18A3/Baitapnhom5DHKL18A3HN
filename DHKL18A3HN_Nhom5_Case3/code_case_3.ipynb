# %%
import numpy as np
print("Đọc file campaign_A.csv: ")
a = np.loadtxt(fname='campaign_A.csv', dtype=str, unpack=True)
print("Đọc file campaign_B.csv: ")
b = np.loadtxt(fname='campaign_B.csv', dtype=str, unpack=True)
# Out:
# Đọc và lưu file campaign_A.csv:
# Đọc và lưu file campaign_B.csv:
