# %%
import numpy as np
print("Đọc dữ liệu campaign_A.csv")
data_A = np.genfromtxt("campaign_A.csv", delimiter=",", dtype=None, names=True, encoding='utf-8')
dates_A = data_A['date']    
visits_A = data_A['visits'] 
print("Campaign A - Dates:", dates_A)
print("Campaign A - Visits:", visits_A) 
print("Đọc dữ liệu từ campaign_B.csv")
data_B = np.genfromtxt("campaign_B.csv", delimiter=",", dtype=None, names=True, encoding='utf-8')
dates_B = data_B['date']
visits_B = data_B['visits']
print("Campaign B - Dates:", dates_B)
print("Campaign B - Visits:", visits_B)
# Out:
# Đọc dữ liệu campaign_A.csv
# Campaign A - Dates: ['2025-01-01' '2025-01-02' '2025-01-03' '2025-01-04' '2025-01-05'
#  '2025-01-06' '2025-01-07' '2025-01-08' '2025-01-09' '2025-01-10'
#  '2025-01-11' '2025-01-12' '2025-01-13' '2025-01-14' '2025-01-15'
#  '2025-01-16' '2025-01-17' '2025-01-18' '2025-01-19' '2025-01-20'
#  '2025-01-21' '2025-01-22' '2025-01-23' '2025-01-24' '2025-01-25'
#  '2025-01-26' '2025-01-27' '2025-01-28' '2025-01-29' '2025-01-30']
# Campaign A - Visits: [1749 2901 2464 2197 1312 5715 1116 2732  585 2416 1041 2940 4841 1425
#  1364 1367 1608 2050 1864 1582 4630 1279  590 1733 1912 2570 1399 2028
#  2185 1093]
# Đọc dữ liệu từ campaign_B.csv
# Campaign B - Dates: ['2025-01-01' '2025-01-02' '2025-01-03' '2025-01-04' '2025-01-05'
#  '2025-01-06' '2025-01-07' '2025-01-08' '2025-01-09' '2025-01-10'
#  '2025-01-11' '2025-01-12' '2025-01-13' '2025-01-14' '2025-01-15'
#  '2025-01-16' '2025-01-17' '2025-01-18' '2025-01-19' '2025-01-20'
#  '2025-01-21' '2025-01-22' '2025-01-23' '2025-01-24' '2025-01-25'
#  '2025-01-26' '2025-01-27' '2025-01-28' '2025-01-29' '2025-01-30']
# Campaign B - Visits: [2436 1479 1086 5994 1736 1132 1841  965 2628 1392 5110 1492 1888 1939
#  1251  497 2373 2685 6565 2036 2652 1068 1272  986  443 1638 4964 2475
#  1578 1434]
