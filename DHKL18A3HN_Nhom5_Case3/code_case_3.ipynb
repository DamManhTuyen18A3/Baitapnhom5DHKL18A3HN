# %%
import numpy as np
data_A = np.genfromtxt("campaign_A.csv", delimiter=",", dtype=None, names=True, encoding='utf-8')
data_B = np.genfromtxt("campaign_B.csv", delimiter=",", dtype=None, names=True, encoding='utf-8')

# Tách cột
dates_A = data_A['Date']
visits_A = data_A['Visits']

dates_B = data_B['Date']
visits_B = data_B['Visits']

print(dates_A, visits_A)
print(dates_B, visits_B)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import numpy as np
#       2 data_A = np.genfromtxt("campaign_A.csv", delimiter=",", dtype=None, names=True, encoding='utf-8')
#       3 data_B = np.genfromtxt("campaign_B.csv", delimiter=",", dtype=None, names=True, encoding='utf-8')
#
# File c:\Users\admin\Downloads\Baitapnhom5DHKL18A3HN\DHKL18A3HN_Nhom5_Case3\numpy.py:3
#       1 import numpy as np
# ----> 3 a = np.loadtxt(fname='campaign_A.csv', dtype=str, unpack=True)
#       5 dates = a[0]
#       6 visits = a[1]
#
# AttributeError: module 'numpy' has no attribute 'loadtxt' (consider renaming 'c:\Users\admin\Downloads\Baitapnhom5DHKL18A3HN\DHKL18A3HN_Nhom5_Case3\numpy.py' if it has the same name as a third-party module you intended to import)
